# %% [markdown]
# # Introducción a Matplotlib
# [Matplotlib](https://matplotlib.org) es una biblioteca que permite la creación de figuras y gráficos de calidad mediente el uso de python.
#
# * Permite la creacion de graficos de manera sencilla y eficiente
# * Permite la integracion de graficos y figuras en Jupyter Notebook.

# %% [markdown]
# ## Import

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# Muestra los graficos integrados de Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ### Representacion grafica de los Datos
#
# si a la función de trazado se le da una matriz de datos, usara como coordenadas en el eje vertical, y utilizara el indice de cada punto d datos en el array como la coordenada horizontal.

# %%
plt.plot ([1,2,3,4,5,6,4,8,9])
plt.show()

# %% [markdown]
# Tambien se pueden proporcionar 2 matrices; una para ek eje horizontal y otra parael eje vertical.

# %%
plt.plot([-3,-1,0,4,7],[1,4,6,7,8])
plt.show()

# %% [markdown]
# Pueden modificarse los ejes de las figuras para que no se mira tan ajustada

# %%
plt.plot([-3,-1,0,4,7],[1,4,6,7,8])
plt.axis([-4,4,0,10]) #[xmin, xmax, ymin, ymax]
plt.show()

# %% [markdown]
# Se sigue el mismo procedimento para pintar una funcion matematica.

# %%
import numpy as np
x = np.linspace(-2,2,500)
y = x**2

plt.plot(x,y)
plt.show()

# %% [markdown]
# Tambien pueden modificsrse el estilo de la grafica para que contenga mas informacion.

# %%
plt.plot(x,y)
plt.title("Square Function")
plt.xlabel("Juanita")
plt.ylabel("y = x**2")
plt.grid(True)
plt.show()

# %% [markdown]
# Pueden superponerse graficos y cambiar el estilo de las lineas

# %%
x = np.linspace(-2,2,500)
y = x**2
y2 = x + 1

plt.plot(x, y, "b--", x, y2, "y")
plt.show()

# %%
# Separado en diferentes lineas las funciones
x= np.linspace(-2,2,500)
y = x**2
y2 = x + 1

plt.title("Square Function")
plt.plot(x, y, "b--")
plt.plot(x, y2, "g")
plt.show()

# %%
# Para poder diferenciar entre las funciones siem9pre es recomendble añadir una leyenda
# Separado en diferentes lineas las funciones
x= np.linspace(-2,2,500)
y = x**2
y2 = x + 1

plt.title("Square Function")
plt.plot(x, y, "b--", label = "x**2")
plt.plot(x, y2, "g", label = "x+1")
plt.legend("best")
plt.show()

# %% [markdown]
# #### Tambien puede Crearse dos graficas que no se superpongan estas graficas se organizan en un grid y se denominan subplots

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2
y2 = x +1

plt.subplot(1, 2, 1)  # 1 rows, 2 columns, 1st subpot
plt.plot(x, y, 'b--')

plt.subplot(1, 2, 2)  # 1 rows, 2 columns 2do subplot
plt.plot(x, y2, 'g')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 y = x**2
#       4 y2 = x +1
# ----> 6 plt.subplot(1, 2, 1)  # 1 rows, 2 columns, 1st subpot
#       7 plt.plot(x, y, 'b--')
#       9 plt.subplot(1, 2, 2)  # 1 rows, 2 columns 2do subplot
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### Scatter Plots

# %%
from numpy.random import rand
x, y = rand(2, 100)
plt.scatter(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from numpy.random import rand
#       2 x, y = rand(2, 100)
# ----> 3 plt.scatter(x, y)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from numpy.random import rand
x, y = rand(2, 100)
x2, y2 = rand(2, 100)
plt.scatter(x, y, c= 'red')
plt.scatter(x2, y2, c = 'blue')
plt.show()

# %% [markdown]
# #### Histogramas

# %%
date = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3,3,3]
plt.subplot(211)
plt.hist(data, bins=10, rwidth=0.8)

plt.subplot(212)
plt.hist(data, bins = [1, 1.2, 2, 2.5, 3], rwidth=0.95)

plt.xlabel("values")
plt.ylabel("Frequency")

# %% [markdown]
# Guardar las graficas

# %%
plt.plot(x,y)
plt.title("Square Function")
plt.xlabel("Juanita")
plt.ylabel("y = x**2")
plt.grid(True)
plt.savefig("Mi_Grafica.png", transparent = True)
